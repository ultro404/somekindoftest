# %% [markdown]
# # Projet - Traitement et analyse de données
#
# <center><img src="https://orange-coast-00c6c7a0f.6.azurestaticapps.net/images/projet/projet_velo.png" width="400"></center>

# %% [markdown]
# ---
#
# ## Informations des étudiant.e.s
#
# **Nom**: <Boucher, Gabrielle>
#
# **Nom**: <Dao, Mélodie>
#
# **Nom**: <Nom, Prénom >
#
# **Groupe**: <>
#
# **Date de remise**: <la_date>

# %% [markdown]
# ---
#
# ## Objectifs
#
# L'objectif principal est de développer un projet informatique visant le traitement et l’affichage de données dans un contexte scientifique.
#
# Plus précisément, vous devrez :
#
# - Importer des données
# - Filtrer des données
# - Nettoyer des données
# - Analyser des données
# - Afficher des données

# %% [markdown]
# ---
#
# ## Consignes
#
# Le projet se déroulera sur les 5 dernières semaines de la session.
# Au cours des 4 premières semaines du projet, vous développerez un programme permettant d'explorer, analyser et visualiser des données.
#
# Lors de la 5e semaine du projet (dernier cours de la session), vous serez évalués.
# Votre programme devra être terminé et fonctionnel avant la dernière séance de cours.
# Votre programme devra être déposé sur Moodle avant la date limite (voir Moodle pour la date limite de votre groupe).
# L'objectif de l'évaluation est de mesurer votre compréhension du travail que vous avez réalisé au cours des semaines précédentes.
#
# Il est aussi possible que l'enseignant vous demande de justifier certaines sections de votre projet (en présentiel ou par Teams).
# Toutes les techniques nécessaires pour la réalisation de ce projet ont été vues dans le cours.
# Si vous utilisez des sources externes, **vous devez l'indiquer**.
# Assurez-vous de bien comprendre l'ensemble du travail que vous remettez, car des questions vous seront posées pour vérifier votre compréhension.
#
#
# <div class="alert alert-block alert-success">
#
# Le projet peut être réalisé en équipe (2 ou 3) ou individuellement.
# Chaque équipe doit remettre une copie de leur propre travail sur Moodle (une remise par équipe).
#
# Les équipes doivent être formées au plus tard avant la fin du cours de la semaine 12.
# Vous DEVEZ envoyer un message par Teams au professeur avec la liste des membres de votre équipe.
#
#
# </div>
#
# <div class="alert alert-block alert-danger">
# À la fin de chaque séance, vous devez remettre votre travail dans la boîte de remise prévue à cet effet sur Moodle.
#
# Vous pourrez continuer à travailler sur votre projet entre chaque séance mais la boite de remise sera fermée.
#
# Ces remises sont des points de contrôle.
#
# Votre programme final devra être déposé sur Moodle **AVANT** la date limite (voir Moodle pour la date limite de votre groupe).
# </div>
#
#
# <div class="alert alert-block alert-success">
# Certaines réponses demandent du code et des explications relatives au code ou aux résultats obtenus.
#
# Faites attention à bien répondre aux bons endroits, le code python dans une cellule de **code** et les réponses textuelles dans une cellule de **Markdown**.
#
# Assurez vous que tout votre *notebook* s'exécute correctement en une seule fois avec le bouton `Run All` ou `Exécuter tout` de VScode. Les cellules de code suivent un ordre, certaines reprennent le résultat d'une précédente. Faites attention à ne pas altérer les données entre deux cellules de code.
#
# Pour vous faciliter cette tâche, utilisez régulièrement le bouton `Run All` ou `Exécuter tout` pour vérifier que l'exécution arrive correctement là où vous êtes, n'attendez pas d'avoir tout codé pour utiliser ce bouton.
# </div>

# %% [markdown]
# ---
#
# ## Mise en situation
#
# Vous faites partie d’une équipe de recherche en sciences du sport qui collabore avec des athlètes utilisant la plateforme Zwift, un simulateur d’entraînement virtuel en cyclisme. Cette plateforme enregistre une grande quantité de données (puissance, cadence, vitesse, fréquence cardiaque, altitude, distance, etc.) pendant chaque session d’entraînement.
#
# L’objectif du projet est d’analyser les performances d’un cycliste à partir de ses données d’entraînement pour mieux comprendre sa progression, ses habitudes et les facteurs qui influencent sa performance. Afin de traiter et visualiser ces données, votre équipe devra :
#
# - Nettoyer et préparer les données pour l’analyse
# - Effectuer divers traitements sur les données afin d’en extraire des indicateurs pertinents
# - Identifier les périodes d’effort intense et de récupération
# - Calculer la vitesse moyenne, la puissance moyenne et d’autres indicateurs de performance
# - Repérer les segments où le cycliste a le plus progressé
# - Visualiser le parcours et les variations d’altitude
# - Détecter d’éventuelles anomalies dans les mesures enregistrées
#
# Votre rôle consiste à écrire un programme en Python capable de lire, nettoyer, transformer et analyser ces données. À travers une série de questions, vous devrez concevoir des fonctions et produire des affichages qui aideront les entraîneurs à interpréter les résultats et à adapter leurs plans d’entraînement.
#
# Voici un vidéo explicatif de l'appliacation Zwift : [**Application Zwift**](https://www.zwift.com/eu-fr/video/how-to-collection/training-basics)
#
#
# ---
#
# Les données disponibles consistent en plusieurs parcours qui ont été réalisés.
# Chaque parcours contient plusieurs listes de données enregistrées pendant la séance :
#
# - `cadence` : nombre de tours de pédale par minute (en rpm – rotations per minute)
# - `altitude` : altitude du cycliste au fil du temps (en mètres)
# - `info` : informations générales du parcours
# - `frequence_cardiaque` : fréquence cardiaque mesurée pendant l’effort (en battements par minute, bpm)
# - `puissance` : puissance développée par le cycliste (en watts, W)
# - `temps` : temps écoulé depuis le début du parcours (en secondes)
# - `x` et `y` : coordonnées du cycliste dans le plan cartésien (en mètres), représentant le déplacement sur le parcours virtuel.
#
# ---

# %% [markdown]
# ## Importation des librairies
#
# Toutes les importations de librairies doivent être faites dans cette section.

# %%
#
# votre code ici
#

# %% [markdown]
# ---
#
#
# ## Importation des données
#
# Les données issues de la plateforme Zwift ont été sauvegardées dans un fichier au format **JSON**. Vous devez importer le contenu de ce fichier et le placer dans la variable `donnees`.

# %%
#
# votre code ici
#

# %% [markdown]
# ---
#
# ## Exploration des données
#
# Dans quel type de structures les données sont-elles contenues ?

# %%
#
# votre code ici
#

# %% [markdown]
# Double-cliquez ici pour ouvrir la capsule et écrire vos réponses! Pour valider votre capsule faite CTRL + ENTREE
#
# <div class="alert alert-block alert-success"><b>
#
# Votre réponse
#
# </b></div>

# %% [markdown]
# Affichez les clefs disponibles.

# %%
#
# votre code ici
#

# %% [markdown]
# Affichez les clefs d'un des éléments (par exemple, le premier parcours).

# %%
#
# votre code ici
#

# %% [markdown]
# **En utilisant Firefox, explorez l'organisation des données.**
# **Expliquez brièvement l'organisation de celles-ci:**
#
# Double-cliquez ici pour ouvrir la capsule et écrire vos réponses! Pour valider votre capsule faite CTRL + ENTREE
#
# <div class="alert alert-block alert-success"><b>
#
# Votre réponse
#
# </b></div>

# %% [markdown]
# **Combien de parcours sont disponibles dans les données?
# Quelles sont les données disponibles pour chacun des parcours?
# Que contient la section info?**
#
#
#
# <div class="alert alert-block alert-success"><b>
#
# Votre réponse
#
# </b></div>

# %% [markdown]
# ---
#
# ## Affichage du parcours
#
# Chaque séance d’entraînement enregistrée dans les données correspond à un parcours contenant les coordonnées successives du cycliste (positions GPS simplifiées).
#
# Écrivez une fonction nommée `afficher_parcours()`.
#
# La fonction doit recevoir en paramètre:
# - un parcours
#
# La fonction doit afficher le déplacement du cycliste à l’aide d’un graphique. Plus précisément :
# - Afficher le trajet parcouru
# - Afficher le point de départ (rouge)
# - Afficher le point d'arriver (bleu)
#
# Voici un exemple de référence pour vous guider dans la présentation attendue.
# N'oubliez pas le titre et le nom des axes.
#
#
# <center><img src="https://orange-coast-00c6c7a0f.6.azurestaticapps.net/images/projet/projet_deplacement_parcours_108.png" width="400"></center>
#
# Indice: Il est possible de superposer différents types de graphiques. Les points rouge et bleu peuvent être ajoutés après la ligne de déplacement

# %%
#
# votre code ici
#

# %% [markdown]
# Affichez le déplacement du `parcours_108` en utilisant la fonction que vous venez de créer.

# %%
#
# votre code ici
#

# %% [markdown]
# ---
#
# ## Nettoyage des données
#
# Dans toute collecte de données, il est courant de rencontrer des valeurs manquantes. Lors de la collecte des données sur Zwift, il arrive que certaines valeurs soient absentes ou erronées. Ces irrégularités peuvent provenir de plusieurs causes : une déconnexion du capteur de puissance ou de fréquence cardiaque, ou encore un problème de transmission des données pendant l’enregistrement de la séance.
#
# Avant de pouvoir effectuer des analyses précises, il est donc nécessaire de détecter et corriger ces données manquantes afin d’obtenir des résultats cohérents et représentatifs de la performance réelle du cycliste.
#
# Affichez le déplacement du `parcours_011` .

# %%
#
# votre code ici
#

# %% [markdown]
# **Que remarquez-vous?**
#
#
#
# <div class="alert alert-block alert-success"><b>
#
# Votre réponse
#
# </b></div>

# %% [markdown]
# Créez une fonction `nettoyer_donnees()` qui permet de remplacer les données manquantes par une estimation de la position.
#
# Cette fonction doit prendre en paramètre **UNE** liste et **retourner** une liste.
#
# Chaque donnée manquante doit être remplacée par la moyenne des valeurs immédiatement avant et après.
#
# Dans le jeu de données que vous avez, les données manquantes sont identifiées par la valeur `None`.
#
# Remarques importantes:
# - Il n'y a pas de données manquantes au début ou à la fin de la liste.
# - Il n'y a pas deux données manquantes de suite.

# %%
#
# votre code ici
#

# %% [markdown]
# Utilisez la fonction que vous venez de créer pour nettoyer les données du `parcours_011`.
#
# Notez qu'il faut nettoyer les données suivantes:
# - `longitude`
# - `latitude`
# - `altitude`

# %%
#
# votre code ici
#

# %% [markdown]
# Affichez les données nettoyées.

# %%
#
# votre code ici
#

# %% [markdown]
# ---
#
# ## Lissage des données
#
# Lors de l’analyse de mesures enregistrées au fil du temps, les données brutes peuvent présenter des fluctuations importantes d’un instant à l’autre. Ces variations rapides ne reflètent pas toujours de réels changements dans la performance : elles peuvent provenir de petites imprécisions dans les capteurs, de retards de transmission ou de légères variations de mesure.
#
# Pour obtenir une vision plus stable et représentative du comportement du cycliste, il est souvent utile d’appliquer un lissage aux données.
# Cette opération consiste à remplacer chaque valeur par une moyenne locale calculée à partir de ses voisines, afin d’atténuer les oscillations trop brusques sans altérer les tendances générales.
#
# Le lissage permet ainsi de mieux visualiser la progression de l’effort et d’interpréter les résultats avec plus de justesse.

# %% [markdown]
# À partir des données d’un parcours, vous devez analyser l’évolution de la puissance développée par le cycliste au fil du temps.
#
# Écrivez une fonction nommée `afficher_puissance(parcours)` qui reçoit en paramètre un `parcours`.
# Cette fonction doit afficher un graphique illustrant la puissance en fonction du temps.
#
# Voici un exemple de ce que la fonction devrait afficher pour le `parcours_127`:
#
# <center><img src="https://orange-coast-00c6c7a0f.6.azurestaticapps.net/images/projet/projet_puissance_parcours_127.png" width="400"></center>
#
# Utilisez la fonction pour afficher la puissance lors du `parcours_127`.

# %%
#
# votre code ici
#

# %% [markdown]
# Écrivez une fonction nommée `lisser(liste, n)` qui reçoit en paramètre une `liste` de valeurs numériques et un entier `n` représentant la taille de la fenêtre de lissage.
#
# La fonction doit **retourner** une nouvelle liste où chaque valeur est remplacée par la moyenne des n valeurs voisines centrées sur elle (ou autant de valeurs disponibles si l’on est près du début ou de la fin de la liste).

# %%
#
# votre code ici
#

# %% [markdown]
# Écrivez un programme qui parcourt tous les éléments de la variable `donnees` et applique la fonction de lissage à la liste de `puissance` de chaque parcours.
#
# Pour chaque parcours, ajoutez une nouvelle clé nommée `puissance_lisse`, dont la valeur sera la liste contenant les puissances lissées.
#
# À la fin de cette étape, chaque dictionnaire de parcours doit donc contenir à la fois :
#
# - la liste originale `puissance`
# - la liste lissée `puissance_lisse`
#
# **Astuce**: Pour repartir des données originales, utilisez `Exécuter tout`

# %%
#
# votre code ici
#

# %% [markdown]
# Affichez le graphique de la `puissance_lisse` en fonction du `temps`, pour le `parcours_127`.

# %%
#
# votre code ici
#

# %% [markdown]
# ---
#
# ## Calcul de la distance
#
# Pour évaluer la performance globale d’un cycliste, la distance totale parcourue est l’une des mesures les plus importantes.
# À partir des coordonnées GPS enregistrées (x et y), il est possible de calculer la distance entre chaque paire de points successifs afin d’obtenir la distance cumulée du parcours.
#
#
# Dans un premier temps, créez une fonction `calculer_distance()` qui **calcule** et **retourne** la distance entre **deux** points.
#
#
# Testez votre fonction avec des points dont vous connaissez la distance qui les sépare.

# %%
#
# votre code ici
#

# %% [markdown]
# À l’aide de la fonction `calculer_distance()`, écrivez un programme qui calcule la distance cumulative tout au long d’un parcours.
# Pour chaque point du trajet, vous devez additionner la distance parcourue depuis le départ.
#
# Ajoutez ensuite la liste complète des distances cumulées au dictionnaire représentant le parcours, sous la clef `distance`.
#
# Ainsi, chaque élément de la liste `distance` correspondra à la distance totale parcourue jusqu’à ce moment du trajet.
#
# Ajoutez l'élément `distance` à chaque parcours.
#
# **Astuce**: Vous devriez réutiliser la fonction `calculer_distance()` pour calculer la distance entre deux points successifs.

# %%
#
# votre code ici
#

# %% [markdown]
# À partir des distances cumulées de chaque parcours, vous devez maintenant calculer la distance totale parcourue pour chaque séance d’entraînement.
#
# Pour chaque parcours de la variable `donnees`, calculez la **distance totale** à partir de la liste `distance` que vous avez créée à l'exercice précédent.
#
# Ajoutez cette valeur dans la section `info` du parcours, sous la clef `distance_totale`.
#
# Ensuite, affichez la distance totale de chaque parcours de manière claire et lisible afin de pouvoir facilement comparer les trajets.
#
# L’affichage doit permettre d’identifier rapidement quel parcours correspond à quelle distance.
#
# Notez que les distances sont enregistrées et calculées en **mètres**, ce qui est correct pour les traitements numériques.
# Toutefois, pour l’affichage des résultats, vous devez convertir les distances en **kilomètres** afin de faciliter la lecture des valeurs

# %%
#
# votre code ici
#

# %% [markdown]
# ---
#
# ## Calcul de la Vitesse
#
# La vitesse est un indicateur essentiel pour analyser la performance d’un cycliste. Elle permet d’évaluer l’intensité de l’effort, la régularité du rythme et l’impact du relief sur le déplacement.
#
# À partir des données de distance et de temps, il est possible de calculer la vitesse instantanée à chaque point du parcours, ainsi que la vitesse moyenne sur l’ensemble du trajet.
#
# Ces mesures offrent une vision plus précise du comportement du cycliste et permettent de comparer les différentes séances d’entraînement, d’identifier les segments les plus rapides ou les plus exigeants, et d’observer l’évolution de la performance au fil du temps.

# %% [markdown]
# À partir des données de `distance` et de `temps`, vous devez maintenant calculer la vitesse du cycliste.
#
# 1. Calculez la **vitesse instantanée** à chaque point du trajet et ajoutez la liste obtenue sous la clé `vitesse`.
#     - La vitesse instantanée doit être exprimée en kilomètre par heure (km/h).
# 1. Calculez ensuite la **vitesse moyenne** et la **vitesse maximale** pour ce même parcours.
#     - Les vitesses moyenne et maximale doivent être exprimées en kilomètre par heure (km/h).
#     - Ajoutez ces deux valeurs dans la section `info` du parcours, sous les clés `vitesse_moyenne` et `vitesse_max`.
#
#
# Vous devez ajouter les vitesses pour chaque parcours de la variable `donnees`.
#
# **Rappel** : Pour obtenir la vitesse instantanée, il suffit de diviser la variation de distance par la variation de temps entre deux points consécutifs.

# %%
#
# votre code ici
#

# %% [markdown]
# À partir des informations ajoutées dans la section info de chaque parcours, vous devez maintenant afficher la **vitesse moyenne** et la **vitesse maximale** pour l’ensemble des parcours contenus dans la variable `donnees`.
#
# L’affichage doit être clair et lisible, afin de permettre une comparaison rapide entre les différentes séances.

# %%
#
# votre code ici
#

# %% [markdown]
# **En observant les vitesses moyennes et maximales affichées pour chaque parcours, remarquez-vous quelque chose d’inhabituel ou d’anormal dans les résultats ?
# Expliquez ce qui semble poser problème et pourquoi certaines valeurs peuvent être irréalistes.**
#
#
# <div class="alert alert-block alert-success"><b>
#
# Votre réponse
#
# </b></div>

# %% [markdown]
# ---
#
# ## Identification des téléportations
#
#
# Sur la plateforme Zwift, les cyclistes peuvent se déplacer librement dans un environnement virtuel, mais ils ont aussi la possibilité de “se téléporter” volontairement à un autre endroit du parcours.
# Cette fonctionnalité est utilisée, par exemple, pour rejoindre un groupe, participer à un événement, ou reprendre un autre trajet sans devoir parcourir la distance entre les deux points.
#
# Lorsqu’une téléportation se produit, la position du cycliste change instantanément dans les données, ce qui crée un saut soudain dans les coordonnées GPS.
#
# Ces téléportations sont donc des actions normales dans le jeu, mais elles doivent être prises en compte et corrigées dans l’analyse des données pour éviter que les vitesses maximales soient faussement exagérées.
#
# Afficher le déplacement pour le `parcours_128`.
#
# Que remarquez-vous?

# %%
#
# votre code ici
#

# %% [markdown]
# Le graphique du déplacement du `parcours_128` illustre bien les téléportations qui sont représentées par de grandes lignes droites reliant des points très éloignés du parcours.
#
# Sur le plan des données, ces téléportations apparaissent comme un saut brusque dans les coordonnées, ce qui explique les lignes droites reliant deux positions éloignées.
#
# Avant de poursuivre les analyses, il sera donc nécessaire d’identifier et corriger ces portions afin d’obtenir un tracé et des vitesses plus représentatifs du parcours réel.
#
#
#
# Pour chacun des parcours de la variable donnees, vous devez :
#
# 1. Analyser la liste des distances afin de repérer les moments où la distance entre deux points successifs est anormalement grande (indice d’une téléportation).
# 2. Conserver les **indices** correspondants à ces téléportations dans une liste.
# 3. Ajouter cette liste dans la section `info` du parcours, sous la clef `teleportations`.
#
#
# Ensuite, affichez les données de téléportation détectés pour chaque parcours, de manière claire et lisible.

# %%
#
# votre code ici
#

# %% [markdown]
# ---
#
# ## Analyse de la Répartition de la Vitesse et de la Puissance
#
# Pour mieux comprendre le profil d’un cycliste, il ne suffit pas d’analyser les moyennes : il est aussi essentiel d’observer comment les valeurs se distribuent au cours d’un parcours.
# Deux cyclistes peuvent avoir la même vitesse moyenne, mais l’un peut rouler de façon constante, tandis que l’autre alterne entre des phases d’effort intense et de récupération.
#
# **L’histogramme** est un outil particulièrement utile pour visualiser cette répartition.
# En représentant la fréquence des différentes vitesses ou puissances, il devient possible d’identifier :
#
# - les plages d’effort les plus fréquentes
# - la régularité du cycliste
# - les zones de haute intensité
#
# Cette analyse permet de mieux caractériser le style de pédalage et de comprendre les stratégies d’effort adoptées pendant l’entraînement.
#
#
# Vous devez produire un histogramme représentant la répartition des vitesses.
#
# Écrivez une fonction nommée `afficher_repartition_vitesse()` qui reçoit en paramètre un **parcours**.
# La fonction doit afficher un **histogramme** montrant la fréquence des différentes vitesses enregistrées.
#
# L’histogramme doit permettre de visualiser les vitesses les plus fréquentes et la forme générale du profil de déplacement du cycliste.
#
#
# Voici un exemple d'affichage pour le `parcours_155`.
#
# <center><img src="https://orange-coast-00c6c7a0f.6.azurestaticapps.net/images/projet/projet_vitesse_parcours_155.png" width="400"></center>
#
# Utilisez votre fonction pour afficher la répartition de vitesse de chaque parcours.

# %%
#
# votre code ici
#

# %% [markdown]
# Réalisez le même type d’analyse que pour la **vitesse**, mais cette fois pour la **puissance**.
#
# Écrivez une fonction nommée `afficher_repartition_puissance()` qui affiche un histogramme représentant la répartition de la `puissance` enregistrées durant le parcours.
#
#
# Voici un exemple d'affichage pour le `parcours_155`.
#
# <center><img src="https://orange-coast-00c6c7a0f.6.azurestaticapps.net/images/projet/projet_puissance_parcours_155.png" width="400"></center>
#
# Utilisez votre fonction pour afficher la répartition de la puissance de chaque parcours.

# %%
#
# votre code ici
#

# %% [markdown]
# ---
#
# ## Calcul du FTP
#
# L’un des indicateurs les plus importants pour évaluer la performance d’un cycliste est le **FTP** (Functional Threshold Power), ou **puissance seuil fonctionnelle**.
#
# Il représente la puissance moyenne maximale qu’un cycliste peut maintenir pendant une période de temps.
#
# Avant de pouvoir estimer cette valeur, il faut d’abord être capable de calculer la puissance moyenne maximale sur une fenêtre mouvante (glissante) de taille variable.
# Cette étape permettra ensuite de déterminer le segment le plus exigeant du parcours et de poser les bases du calcul du FTP.

# %% [markdown]
# Écrivez une fonction nommée `puissance_fenetre_max()` qui reçoit en paramètres :
#
# - un `parcours` : contenant notamment la puissance
# - une `fenetre` : un entier représentant la largeur de la fenêtre (en secondes).
#
# La fonction doit :
#
# 1. Parcourir la liste des puissances et calculer la puissance moyenne pour chaque fenêtre consécutive de taille n
# 2. Déterminer la valeur maximale parmi toutes ces moyennes
# 3. Retourner cette puissance moyenne maximale (en watts).

# %%
#
# votre code ici
#

# %% [markdown]
# Afin d’analyser l’évolution de la puissance moyenne en fonction de la durée de l’effort, vous devez produire un graphique à ligne illustrant la puissance moyenne maximale pour différentes largeurs de fenêtre.
#
# Pour ce faire :
#
# 1. Identifiez les largeurs de fenêtres
# 2. Pour chacune de ces largeurs, utilisez votre fonction `puissance_fenetre_max()` pour calculer la puissance moyenne maximale correspondante.
# 3. Tracez un graphique où :
#     - l’axe X représente la durée de la fenêtre
#     - l’axe Y représente la puissance moyenne maximale (en watts).
#
# Voici un exemple de graphique pour le `parcours_159`:
#
# <center><img src="https://orange-coast-00c6c7a0f.6.azurestaticapps.net/images/projet/projet_FTP_parcours_159.png" width="400"></center>

# %%
#
# votre code ici
#

# %% [markdown]
# ---
#
# ## Calcul de la pente
#
#
# L’un des éléments clés pour analyser la performance d’un cycliste est la pente du terrain. Elle influence directement la puissance nécessaire pour maintenir une vitesse donnée et permet d’expliquer les variations observées dans les données.
#
# À partir des informations de distance et d’altitude, il est possible de calculer la pente instantanée du parcours, exprimée en pourcentage (%).
# Une pente positive indique une montée, tandis qu’une pente négative correspond à une descente.
#
# L’analyse de la pente permet de mieux comprendre comment le relief du parcours affecte la vitesse, la cadence et la puissance du cycliste tout au long de l’entraînement.

# %% [markdown]
# À partir des données de **distance** et **d’altitude**, vous devez calculer la pente instantanée du parcours pour chaque point.
#
# Écrivez une fonction nommée `calculer_pente()` qui reçoit en paramètre un un parcours.
#
# La fonction doit :
# 1. Calculer la variation d’altitude (`Δh`) et la variation de distance horizontale (`Δd`) entre chaque paire de points successifs ;
# 2. Déterminer la pente en pourcentage à l’aide de la formule :
#
#    $$
#    \text{pente} = \frac{Δh}{Δd} \times 100
#    $$
#
# 3. Ajouter la liste des pentes calculées au dictionnaire du parcours sous la clé pente.
#
# **Note** : la pente peut être positive (montée) ou négative (descente).
#
# ⚠️ Attention – Utilisation de données lissées
#
# Les calculs de pente peuvent être très sensibles aux variations dans les données de distance et d’altitude.
# Pour obtenir des résultats plus réalistes, vous devriez utiliser les versions lissées de ces données (par exemple distance_lissee et altitude_lissee), puis lisser également la pente obtenue.
#
# 🔹 Important : ne modifiez pas directement les listes dans le dictionnaire parcours.
# Faites plutôt une copie de vos données avant d’appliquer le lissage, afin de préserver les valeurs originales.
#
# 💡 Vous pouvez vous appuyer sur les graphiques d’altitude pour vérifier si vos calculs donnent des résultats cohérents.
#
# Voici un exemple pour le `parcours_130`. Notez que le rendu ne sera pas exactement identique pour tout le monde : il varie selon les paramètres de fenêtrage choisis, notamment la largeur de la fenêtre utilisée pour le lissage.
#
# <center><img src="https://orange-coast-00c6c7a0f.6.azurestaticapps.net/images/projet/projet_pente_parcours_130.png" width="400"></center>

# %%
#
# votre code ici
#

# %% [markdown]
# À partir des valeurs de **pente**, vous devez maintenant déterminer la montée totale effectuée par le cycliste pendant chaque parcours.
#
# Pour chaque **parcours** de la variable `donnees` :
#
# - Parcourez la liste des pentes et additionnez uniquement les portions positives (les montées).
# - Ajoutez cette valeur dans la section `info` du parcours, sous la clef `montee_totale`.
#
# Affichez ensuite la **montée totale** pour chacun des parcours de façon claire et lisible, afin de pouvoir facilement comparer la quantité totale de dénivelé positif entre les séances.

# %%
#
# votre code ici
#

# %% [markdown]
# ---
#
# ## Affichage du déplacement avec téléportations
#
# Vous devez maintenant afficher le graphique du déplacement du cycliste tout en tenant compte des téléportations détectées dans les parcours.
#
# À partir des coordonnées `x` et `y`, affichez la trajectoire complète du cycliste.
# Les portions normales du parcours doivent être représentées par une ligne continue, tandis que les segments correspondant aux téléportations (selon les indices contenus dans `info["teleportations"]`) doivent être tracés avec une ligne en tirets ("--").
#
# **Astuce** : Vous pouvez tracer le parcours segment par segment — en changeant le style de ligne (`linestyle`) lorsqu’une téléportation est détectée.
#
# Voici un exemple d'affichage pour le `parcours_128`.
#
# <center><img src="https://orange-coast-00c6c7a0f.6.azurestaticapps.net/images/projet/projet_teleportation_parcours_128.png" width="400"></center>

# %%
#
# votre code ici
#

# %% [markdown]
# ---
#
#
# ## Affichage du déplacement selon la vitesse
#
# Le simple tracé du parcours ne suffit pas toujours pour comprendre la performance du cycliste.
# En ajoutant l’information de vitesse au graphique, il devient possible de visualiser directement les variations d’intensité tout au long du trajet.
#
# Les zones plus rapides ou plus lentes se distinguent alors par leur couleur, ce qui permet d’observer :
#
# - les segments où le cycliste accélère ou ralentit
# - l’impact du relief ou des virages
# - et la régularité du rythme sur l’ensemble du parcours
#
# Cette visualisation offre une représentation claire et intuitive du comportement du cycliste dans l’espace.
#
#
#
# Vous devez maintenant afficher le graphique du déplacement du cycliste en représentant la vitesse par des couleurs.
#
# À partir des coordonnées x et y et de la liste des vitesses (vitesse), tracez le parcours en segments colorés selon la vitesse instantanée :
#
# - Bleu : moins de 25 km/h
# - Vert : entre 25 et 30 km/h
# - Orange : entre 30 et 35 km/h
# - Rouge : 35 km/h et plus
#
#
#
# Voici un exemple d'affichage pour le `parcours_155`.
#
# <center><img src="https://orange-coast-00c6c7a0f.6.azurestaticapps.net/images/projet/projet_vitesse_trajet_parcours_155.png" width="400"></center>

# %%
#
# votre code ici
#
